# %% [markdown]
# ##### Ana Daley (amd2yc@virginia.edu)
# ##### DS 5001
# ##### 06 May 22

# %%
import pandas as pd

# %%
OHCO = ['title', 'chap_num', 'para_num', 'sent_num', 'token_num']

# %%
LIB = pd.read_csv('CORPUS.csv')

# %%
Titles = pd.Series(['DON QUIXOTE',
          'THE LADY CORNELIA',
          'RINCONETE AND CORTADILLO',
          'THE LICENTIATE VIDRIERA; OR, DOCTOR GLASS-CASE',
          'THE DECEITFUL MARRIAGE',
          'DIALOGUE BETWEEN SCIPIO AND BERGANZA',
          'THE LITTLE GIPSY GIRL',
          'THE GENEROUS LOVER',
          'THE SPANISH-ENGLISH LADY',
          'THE FORCE OF BLOOD',
          'THE JEALOUS ESTRAMADURAN',
          'THE ILLUSTRIOUS SCULLERY-MAID',
          'THE TWO DAMSELS',
          'DON QUIJOTE',
          'LA JITANILLA',
          'EL AMANTE LIBERAL',
          'RINCONETE Y CORTADILLO',
          'LA ESPAÑOLA INGLESA',
          'EL LICENCIADO VIDRIERA',
          'LA FUERZA DE LA SANGRE',
          'EL CELOSO ESTREMEÑO',
          'LA ILUSTRE FREGONA',
          'LAS DOS DONCELLAS',
          'LA SEÑORA CORNELIA',
          'EL CASAMIENTO ENGAÑOSO',
          'COLOQUIO QUE PASÓ ENTRE CIPION Y BERGANZA',
          'LA TIA FINGIDA'])

# %%
LIB = pd.DataFrame(Titles).rename(columns={0:'Title'})

# %%
LIB['Author'] = 'Miguel de Cervantes Saavedra'
LIB['Translator'] = 'Walter K. Kelly'
LIB['Translator'][13:] = 'NA'
LIB['Language'] = 'English'
LIB['Language'][13:] = 'Spanish'
LIB['Year'] = '1613'
LIB['Year'][0] = '1605'
LIB['Year'][13] = '1605'
LIB['Source'] = 'Project Gutenburg'
LIB['Format'] = 'plaintext'
LIB['Encoding'] = 'utf-8'

# %%
LIB
# Out:
#                                              Title  \
# 0                                      DON QUIXOTE
# 1                                THE LADY CORNELIA
# 2                         RINCONETE AND CORTADILLO
# 3   THE LICENTIATE VIDRIERA; OR, DOCTOR GLASS-CASE
# 4                           THE DECEITFUL MARRIAGE
# 5             DIALOGUE BETWEEN SCIPIO AND BERGANZA
# 6                            THE LITTLE GIPSY GIRL
# 7                               THE GENEROUS LOVER
# 8                         THE SPANISH-ENGLISH LADY
# 9                               THE FORCE OF BLOOD
# 10                        THE JEALOUS ESTRAMADURAN
# 11                   THE ILLUSTRIOUS SCULLERY-MAID
# 12                                 THE TWO DAMSELS
# 13                                     DON QUIJOTE
# 14                                    LA JITANILLA
# 15                               EL AMANTE LIBERAL
# 16                          RINCONETE Y CORTADILLO
# ...

# %%
LIB.to_csv('LIB.csv', index=False)
